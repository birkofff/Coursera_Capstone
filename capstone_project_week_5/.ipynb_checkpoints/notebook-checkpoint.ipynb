# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim

# %%
dataset = pd.read_csv("level_crime.csv")
dataset.head()
# Out:
#                    MajorText                          MinorText  \
# 0  Arson and Criminal Damage                              Arson
# 1  Arson and Criminal Damage                    Criminal Damage
# 2                   Burglary  Burglary - Business and Community
# 3                   Burglary             Burglary - Residential
# 4              Drug Offences                   Drug Trafficking
#
#      LookUp_BoroughName  201807  201808  201809  201810  201811  201812  \
# 0  Barking and Dagenham       6       5       3       8       5       1
# 1  Barking and Dagenham     127     101     107     132     105      88
# 2  Barking and Dagenham      30      18      33      32      39      33
# 3  Barking and Dagenham      94      84      99      94     106     164
# 4  Barking and Dagenham       8       7      10       7       7       4
#
#    201901  ...  201909  201910  201911  201912  202001  202002  202003  \
# 0       5  ...       6       9       8       6       4       5       6
# ...

# %%
dataset.shape
# Out:
# (1569, 27)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                         MajorText                           MinorText  \
# 0       Arson and Criminal Damage                               Arson
# 1       Arson and Criminal Damage                     Criminal Damage
# 2                        Burglary   Burglary - Business and Community
# 3                        Burglary              Burglary - Residential
# 4                   Drug Offences                    Drug Trafficking
# ...                           ...                                 ...
# 1564             Vehicle Offences          Theft from a Motor Vehicle
# 1565             Vehicle Offences  Theft or Taking of a Motor Vehicle
# 1566  Violence Against the Person                            Homicide
# 1567  Violence Against the Person                Violence with Injury
# 1568  Violence Against the Person             Violence without Injury
#
#         LookUp_BoroughName  201807  201808  201809  201810  201811  201812  \
# ...

# %%
dataset.head()
# Out:
#                    MajorText                          MinorText  \
# 0  Arson and Criminal Damage                              Arson
# 1  Arson and Criminal Damage                    Criminal Damage
# 2                   Burglary  Burglary - Business and Community
# 3                   Burglary             Burglary - Residential
# 4              Drug Offences                   Drug Trafficking
#
#      LookUp_BoroughName  201807  201808  201809  201810  201811  201812  \
# 0  Barking and Dagenham       6       5       3       8       5       1
# 1  Barking and Dagenham     127     101     107     132     105      88
# 2  Barking and Dagenham      30      18      33      32      39      33
# 3  Barking and Dagenham      94      84      99      94     106     164
# 4  Barking and Dagenham       8       7      10       7       7       4
#
#    201901  ...  201909  201910  201911  201912  202001  202002  202003  \
# 0       5  ...       6       9       8       6       4       5       6
# ...

# %%
data=dataset.copy()

# %%
data.drop(["MajorText", "MinorText","LookUp_BoroughName"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    201807  201808  201809  201810  201811  201812  201901  201902  201903  \
# 0       6       5       3       8       5       1       5       2       5
# 1     127     101     107     132     105      88      97     127     138
# 2      30      18      33      32      39      33      45      24      29
# 3      94      84      99      94     106     164     114     107      99
# 4       8       7      10       7       7       4       5       2       6
#
#    201904  ...  201909  201910  201911  201912  202001  202002  202003  \
# 0       5  ...       6       9       8       6       4       5       6
# 1     130  ...     109     109      97     121      97     103     107
# 2      27  ...      37      30      30      25      31      17      28
# 3      96  ...      80      97     114     130     116     123      97
# 4       5  ...       7       8      13       3      14       5       6
#
#    202004  202005  202006
# 0       2       2       4
# 1      80      86     121
# ...

# %%
dataset["Total"]=data.sum(axis=1)

# %%
dataset.head()
# Out:
#                    MajorText                          MinorText  \
# 0  Arson and Criminal Damage                              Arson
# 1  Arson and Criminal Damage                    Criminal Damage
# 2                   Burglary  Burglary - Business and Community
# 3                   Burglary             Burglary - Residential
# 4              Drug Offences                   Drug Trafficking
#
#      LookUp_BoroughName  201807  201808  201809  201810  201811  201812  \
# 0  Barking and Dagenham       6       5       3       8       5       1
# 1  Barking and Dagenham     127     101     107     132     105      88
# 2  Barking and Dagenham      30      18      33      32      39      33
# 3  Barking and Dagenham      94      84      99      94     106     164
# 4  Barking and Dagenham       8       7      10       7       7       4
#
#    201901  ...  201910  201911  201912  202001  202002  202003  202004  \
# 0       5  ...       9       8       6       4       5       6       2
# ...

# %%
dataset_final = dataset[["MajorText", "MinorText","LookUp_BoroughName","Total"]]
dataset_final.head()
# Out:
#                    MajorText                          MinorText  \
# 0  Arson and Criminal Damage                              Arson
# 1  Arson and Criminal Damage                    Criminal Damage
# 2                   Burglary  Burglary - Business and Community
# 3                   Burglary             Burglary - Residential
# 4              Drug Offences                   Drug Trafficking
#
#      LookUp_BoroughName  Total
# 0  Barking and Dagenham    119
# 1  Barking and Dagenham   2687
# 2  Barking and Dagenham    683
# 3  Barking and Dagenham   2323
# 4  Barking and Dagenham    181

# %%
dataset_final.rename(columns = {'MajorText': 'MajorCategory', 'MinorText': 'MinorCategory','LookUp_BoroughName':'Boroughs'},inplace = True)
dataset_final.head()
# Out:
# C:\Users\jake brown\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#                MajorCategory                      MinorCategory  \
# 0  Arson and Criminal Damage                              Arson
# 1  Arson and Criminal Damage                    Criminal Damage
# 2                   Burglary  Burglary - Business and Community
# 3                   Burglary             Burglary - Residential
# 4              Drug Offences                   Drug Trafficking
#
#                Boroughs  Total
# 0  Barking and Dagenham    119
# 1  Barking and Dagenham   2687
# 2  Barking and Dagenham    683
# 3  Barking and Dagenham   2323
# 4  Barking and Dagenham    181

# %%
data = dataset_final[['Boroughs','Total']].groupby(['Boroughs']).Total.sum().to_frame().reset_index()

# %%
data.head(10)
# Out:
#                Boroughs  Total
# 0  Barking and Dagenham  38788
# 1                Barnet  59213
# 2                Bexley  33692
# 3                 Brent  59921
# 4               Bromley  47612
# 5                Camden  72764
# 6               Croydon  66117
# 7                Ealing  60522
# 8               Enfield  58648
# 9             Greenwich  54851

# %%
data.Boroughs.describe()
# Out:
# count             33
# unique            33
# top       Hillingdon
# freq               1
# Name: Boroughs, dtype: object

# %%
dataset_final.describe()
# Out:
#               Total
# count   1569.000000
# mean    1106.601657
# std     2293.069960
# min        1.000000
# 25%       17.000000
# 50%      113.000000
# 75%     1188.000000
# max    37857.000000

# %%
coords = pd.read_json("coordinates.json")

# %%
coords.head()
# Out:
#           DD              DMS     geohash                                  UTM
# lat  51.5607  51Âº33'38.52" N  u10j7d36u5  31U 302850.05503661 5716014.1691097
# lng   0.1557   0Âº09'20.52" E  u10j7d36u5  31U 302850.05503661 5716014.1691097

# %%
import operator

non_null_geolocate_column = geolocate_column[~geolocate_column.isnull()]
io['latitude'] = None
io['latitude'] = non_null_geolocate_column.apply(operator.attrgetter('latitude'))
io['longitude'] = None
io['longitude'] = non_null_geolocate_column.apply(operator.attrgetter('longitude'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8f3cdf1bcfd4> in <module>
#       1 import operator
#       2
# ----> 3 non_null_geolocate_column = geolocate_column[~geolocate_column.isnull()]
#       4 io['latitude'] = None
#       5 io['latitude'] = non_null_geolocate_column.apply(operator.attrgetter('latitude'))
#
# NameError: name 'geolocate_column' is not defined

# %%
Latitude = []
Longitude = []
geolocator = Nominatim(user_agent="ny_explorer")
for Boroughs in dataset_final:
    location = geolocator.geocode(Boroughs)
    if location is None:
        location = "Nan"
    Latitude.append(location.latitude)
    Longitude.append(location.longitude) 

#dataset_final['Latitude'] = Latitude
#dataset_final['Longitude'] = Longitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-c7a30dacd43b> in <module>
#       6     if location is None:
#       7         location = "Nan"
# ----> 8     Latitude.append(location.latitude)
#       9     Longitude.append(location.longitude)
#      10
#
# AttributeError: 'str' object has no attribute 'latitude'
